# %%
import pandas as pd

# Assuming the file path is correctly set to your Excel file
file_path = 'BU_Spark_20240117.xlsx'
xls = pd.ExcelFile(file_path)
print(xls.sheet_names)
# Out:
# ['Documentation_Base', 'Base_bundle', 'Documentation_grants', 'Grants']

# %%
df_base_bundle = pd.read_excel(file_path, sheet_name='Base_bundle')
df_grants = pd.read_excel(file_path, sheet_name='Grants')

print(df_base_bundle.head())
print(df_grants.head())
# Out:
# c:\Users\Ethan\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#    record_id form_type         ein                        organization_name  \
# 0    6064945        PF  82-1564028                 David Goldman Foundation
# 1    7103184        PF  27-1511873  Iron Mountain Charitable Foundation Inc
# 2    6029538        PF  46-1578421     Elissa Bradley Charitable Foundation
# 3    6272105        PF  27-1962720                     Sound Foundation Inc
# 4    6104119        PF  85-1280554                 Alice L White Foundation
#
#   organization_name.1 org_profile_name period_end  months_covered   fye  \
# 0                 NaN              NaN 2020-12-31              12  2020
# 1                 NaN              NaN 2020-12-31              12  2020
# 2                 NaN              NaN 2020-12-31              12  2020
# ...

# %%
african_code = 'PE030000'
latin_american_code = 'PE050000'

# For the base bundle DataFrame
df_base_bundle['serves_combined_population'] = df_base_bundle['pcs_population'].str.contains(african_code) | df_base_bundle['pcs_population'].str.contains(latin_american_code)

# For the grants DataFrame
df_grants['serves_combined_population'] = df_grants['recip_population_code'].str.contains(african_code) | df_grants['recip_population_code'].str.contains(latin_american_code)

# %%
# Total Revenue
revenue_by_organization = filtered_df[['organization_name','total_revenue']]
revenue_by_organization
# Out:
#                         organization_name  total_revenue
# 19491                     Casa Latina Inc        18211.0
# 19694              African Bridge Network        94623.0
# 19891  Haitian American Business Expo Inc        72345.0
# 19892  Haitian American Business Expo Inc        74238.0
# 19994                   Robbins House Inc        88100.0
# ...                                   ...            ...
# 62746         Boston Senior Home Care Inc     46611722.0
# 62760      Project Step Inc Symphony Hall      1064600.0
# 62843              Full Steam Forward Inc      1265399.0
# 62856                   Mision De Caridad       126790.0
# 62860                     Love Your Magic       132787.0
#
# [341 rows x 2 columns]

# %%
total_amount_per_organization = filtered_grants_df.groupby('gm_name')['amount_usd'].sum().sort_values(ascending=False)
print(total_amount_per_organization)
# Out:
# gm_name
# MacKenzie Scott                                                  5000000
# Silicon Valley Community Foundation                              4612000
# The Boston Foundation                                            3945890
# Greater Worcester Community Foundation, Inc.                     2738322
# Masshire Hampden County Workforce Board, Inc.                    2494501
#                                                                   ...
# JPMORGAN CHASE FOUNDATION                                            100
# American Express Foundation                                           85
# The Melvin & Beatrice Fraiman Charitable Foundation                   50
# The J R Stein Family Foundation (f/k/a the Stein Family Fund)         25
# The Lazard Foundation C/o Lazard Freres & Co LLC                      25
# Name: amount_usd, Length: 573, dtype: int64
